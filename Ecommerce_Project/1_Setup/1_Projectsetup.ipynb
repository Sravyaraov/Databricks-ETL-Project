# %% [markdown]
# **Project intial setup-**CREATE CATALOG****

# %%
# %sql

CREATE CATALOG IF NOT EXISTS ecommerce;

# %% [markdown]
# USE CATALOG

# %%
# %sql

USE CATALOG ecommerce; --code you run after this line will use ecommerce catalog

# %% [markdown]
# CREATE SCHEMA

# %%
# %sql

CREATE SCHEMA IF NOT EXISTS ecommerce.bronze;
CREATE SCHEMA IF NOT EXISTS ecommerce.silver;
CREATE SCHEMA IF NOT EXISTS ecommerce.gold;

# %% [markdown]
# CHECK STRUCTURE IN CATALOG

# %%
# %sql

SHOW DATABASES FROM ecommerce;

--if you want to delete entire catalog
--DROP CATALOG IF EXISTS ecommerce CASCADE;
